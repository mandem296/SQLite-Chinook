# %% [markdown]
# <a href="https://colab.research.google.com/github/mandem296/SQLite-Chinook/blob/main/SQLite_PowerBi_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SQL & POWERBI CHALLENGE**

# %% [markdown]
# ## Accessing file on Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Installing mysql to run commands

# %%
#Installing mysql on the Google Colab so that we can input SQL commands
# !pip install pymysql
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.5 MB/s eta 0:00:00
# ...

# %%
#magic command start with % . this is to load a sql extensions

# %load_ext sql

# %% [markdown]
# ## Loading Chinook DB

# %%
#if you want to write the path where the file is located just go to the file, right-click and select copy path then paste the path after '///' as seem below:
# %sql sqlite:////content/drive/MyDrive/SQLite/chinook.db

# %% [markdown]
# ## Chinook DB Overview

# %% [markdown]
# ![Screenshot 2023-09-29 at 20.36.34.png](data:image/png;base64,...)

# %% [markdown]
# ## Exploring the Database

# %%
#shows tables contained in the Chinook Database
# %%sql
SELECT name FROM sqlite_master WHERE type IN ('table','view') AND name NOT LIKE 'sqlite_%' ORDER BY 1
# Out:
#  * sqlite:////content/drive/MyDrive/SQLite/chinook.db
# Done.
# [('albums',),
#  ('artists',),
#  ('customers',),
#  ('employees',),
#  ('genres',),
#  ('invoice_items',),
#  ('invoices',),
#  ('media_types',),
#  ('playlist_track',),
#  ('playlists',),
#  ('tracks',)]

# %% [markdown]
# ### Basic SQL Query Structures:
#
#
#
# 1.   Statements
# 2.   Clauses
# 1.   Operations
# 2.   Built-in Functions
# 1.   Comments

# %% [markdown]
# **Comments:**
#
#
# 1.   Single Line Comments
# (We use the --)
# 2.   Multiline comment:
# (we use /* */)

# %% [markdown]
# ### SELECT STATEMENT
# SELECT Column_name
#
# FROM TABLE

# %%
#Syntax
# %%sql

#The code below provides the names in the column 'first names' in the 'customers' table.
SELECT FirstName
FROM customers
# Out:
#  * sqlite:////content/drive/MyDrive/SQLite/chinook.db
# Done.
# [('Luís',),
#  ('Leonie',),
#  ('François',),
#  ('Bjørn',),
#  ('František',),
#  ('Helena',),
#  ('Astrid',),
#  ('Daan',),
#  ('Kara',),
#  ('Eduardo',),
#  ('Alexandre',),
#  ('Roberto',),
#  ('Fernanda',),
#  ('Mark',),
#  ('Jennifer',),
#  ('Frank',),
#  ('Jack',),
#  ('Michelle',),
#  ('Tim',),
#  ('Dan',),
#  ('Kathy',),
#  ('Heather',),
#  ('John',),
#  ('Frank',),
#  ('Victor',),
#  ('Richard',),
#  ('Patrick',),
#  ('Julia',),
#  ('Robert',),
#  ('Edward',),
#  ('Martha',),
#  ('Aaron',),
#  ('Ellie',),
#  ('João',),
#  ('Madalena',),
#  ('Hannah',),
#  ('Fynn',),
#  ('Niklas',),
#  ('Camille',),
#  ('Dominique',),
#  ('Marc',),
#  ('Wyatt',),
#  ('Isabelle',),
#  ('Terhi',),
#  ('Ladislav',),
#  ('Hugh',),
#  ('Lucas',),
#  ('Johannes',),
#  ('Stanisław',),
#  ('Enrique',),
#  ('Joakim',),
#  ('Emma',),
#  ('Phil',),
#  ('Steve',),
#  ('Mark',),
#  ('Diego',),
#  ('Luis',),
#  ('Manoj',),
#  ('Puja',)]

# %% [markdown]
# ### Limiting Query Output
#
# -We do this because we might deal with big data.

# %%
# %%sql
#
# #We are going to limit to only 10 names. Remember to indicate semi-colon to signify end of code.
# SELECT FirstName
# FROM customers
#
# LIMIT 10;
# Out:
#  * sqlite:////content/drive/MyDrive/SQLite/chinook.db
# Done.
# [('Luís',),
#  ('Leonie',),
#  ('François',),
#  ('Bjørn',),
#  ('František',),
#  ('Helena',),
#  ('Astrid',),
#  ('Daan',),
#  ('Kara',),
#  ('Eduardo',)]

# %% [markdown]
# ### Reading data in multiple columns in a particular table

# %%
#We are going to limit to only 10 names. Remember to indicate semi-colon to signify end of code.
# %%sql

SELECT FirstName,
       LastName,
       Company

FROM customers

LIMIT 20;
# Out:
#  * sqlite:////content/drive/MyDrive/SQLite/chinook.db
# Done.
# [('Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.'),
#  ('Leonie', 'Köhler', None),
#  ('François', 'Tremblay', None),
#  ('Bjørn', 'Hansen', None),
#  ('František', 'Wichterlová', 'JetBrains s.r.o.'),
#  ('Helena', 'Holý', None),
#  ('Astrid', 'Gruber', None),
#  ('Daan', 'Peeters', None),
#  ('Kara', 'Nielsen', None),
#  ('Eduardo', 'Martins', 'Woodstock Discos'),
#  ('Alexandre', 'Rocha', 'Banco do Brasil S.A.'),
#  ('Roberto', 'Almeida', 'Riotur'),
#  ('Fernanda', 'Ramos', None),
#  ('Mark', 'Philips', 'Telus'),
#  ('Jennifer', 'Peterson', 'Rogers Canada'),
#  ('Frank', 'Harris', 'Google Inc.'),
#  ('Jack', 'Smith', 'Microsoft Corporation'),
#  ('Michelle', 'Brooks', None),
#  ('Tim', 'Goyer', 'Apple Inc.'),
#  ('Dan', 'Miller', None)]

# %%
#Question: Retrieve first 10 tracks from tracks table but only 'Trackid','Name' and 'Albumid' columns are required.

# %%sql

SELECT Trackid, Name, Albumid

FROM tracks

LIMIT 10;
# Out:
#  * sqlite:////content/drive/MyDrive/SQLite/chinook.db
# Done.
# [(1, 'For Those About To Rock (We Salute You)', 1),
#  (2, 'Balls to the Wall', 2),
#  (3, 'Fast As a Shark', 3),
#  (4, 'Restless and Wild', 3),
#  (5, 'Princess of the Dawn', 3),
#  (6, 'Put The Finger On You', 1),
#  (7, "Let's Get It Up", 1),
#  (8, 'Inject The Venom', 1),
#  (9, 'Snowballed', 1),
#  (10, 'Evil Walks', 1)]

# %% [markdown]
# ### Reading data from all columns in a table in the database

# %%
#use * to select all  data from the table 'employees'

# %%sql

SELECT *

FROM employees

LIMIT 15;
# Out:
#  * sqlite:////content/drive/MyDrive/SQLite/chinook.db
# Done.
# [(1, 'Adams', 'Andrew', 'General Manager', None, '1962-02-18 00:00:00', '2002-08-14 00:00:00', '11120 Jasper Ave NW', 'Edmonton', 'AB', 'Canada', 'T5K 2N1', '+1 (780) 428-9482', '+1 (780) 428-3457', 'andrew@chinookcorp.com'),
#  (2, 'Edwards', 'Nancy', 'Sales Manager', 1, '1958-12-08 00:00:00', '2002-05-01 00:00:00', '825 8 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 2T3', '+1 (403) 262-3443', '+1 (403) 262-3322', 'nancy@chinookcorp.com'),
#  (3, 'Peacock', 'Jane', 'Sales Support Agent', 2, '1973-08-29 00:00:00', '2002-04-01 00:00:00', '1111 6 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 5M5', '+1 (403) 262-3443', '+1 (403) 262-6712', 'jane@chinookcorp.com'),
#  (4, 'Park', 'Margaret', 'Sales Support Agent', 2, '1947-09-19 00:00:00', '2003-05-03 00:00:00', '683 10 Street SW', 'Calgary', 'AB', 'Canada', 'T2P 5G3', '+1 (403) 263-4423', '+1 (403) 263-4289', 'margaret@chinookcorp.com'),
# ...
